# %%
#import libraries and import the raw data file
import pandas as pd
data = pd.read_excel('indger_events.xlsx')
data.to_csv()
data.head()
# Out:
#           eventname start date   end date  region
# 0  Lockdown Phase 1 2020-03-25 2020-04-14       2
# 1  Lockdown Phase 2 2020-04-15 2020-05-03       2
# 2  Lockdown Phase 3 2020-05-04 2020-05-17       2
# 3  Lockdown Phase 4 2020-05-18 2020-05-31       2
# 4     Janata Curfew 2020-03-22 2020-03-22       2

# %%
#save the file in csv format
data.to_csv('indger_events.csv')

# %%
data
# Out:
#                                             eventname start date   end date  \
# 0                                    Lockdown Phase 1 2020-03-25 2020-04-14
# 1                                    Lockdown Phase 2 2020-04-15 2020-05-03
# 2                                    Lockdown Phase 3 2020-05-04 2020-05-17
# 3                                    Lockdown Phase 4 2020-05-18 2020-05-31
# 4                                       Janata Curfew 2020-03-22 2020-03-22
# 5   Relaxation on shops/e-commerce dealing with es... 2020-05-04 2020-05-17
# 6     Relaxation on private offices with 33% capacity 2020-05-04 2020-05-17
# 7      Relaxation on 2-wheelers without pillion rider 2020-05-04 2020-05-17
# 8   Relaxation on 4-wheelers with 1 driver and 2 p... 2020-05-04 2020-05-17
# 9         Relaxation on inter-state movement of goods 2020-05-04 2020-05-17
# 10             Economic Package of 20 trillion rupees 2020-05-12 2020-12-31
# ...
